# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as  plt 

pages = pages = ["https://www.kammi.it/scarpe-donna/sneakers/",
                 "https://www.kammi.it/scarpe-donna/sneakers/pag2/"]

dict = {"modello": [], "descrizione": [], "prezzo": []}

for url in pages:
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        modelli = soup.find_all("p", attrs={"class": "product-title"})
        descrizioni = soup.find_all("p", attrs={"class": "product-description"})
        prezzi = soup.find_all("p", attrs={"class": "product-price"})
        
        prezzi_clean = [prezzo.text for i, prezzo in enumerate(prezzi) if i % 2 != 0]
        
        for modello, descrizione, prezzo in zip(modelli, descrizioni, prezzi_clean):
            dict["categoria"] = "sneakers"
            dict["modello"].append(modello.text.strip())
            dict["descrizione"].append(descrizione.text.strip())
            dict["prezzo"].append(prezzo.replace("€","").replace(",",".").strip())

df1= pd.DataFrame(dict)
df1
# Out:
#                  modello                                        descrizione  \
# 0         Sneakers 82066  Sneakers in pelle bianca con inserti verde men...
# 1         Sneakers 82066  Sneakers in pelle bianca con inserti laminato ...
# 2         Sneaker Marina  Sneakers in pelle bianca con tallonetta in gli...
# 3         Sneaker Marina  Sneakers in pelle bianca con tallonetta in gli...
# 4           Sneaker Nina  Sneakers in pelle bianca, saetta in pelle e gl...
# 5          Sneakers 8100  Sneakers in nappa bianca forata con tallonetta...
# 6          Sneakers 8100  Sneakers in nappa bianca forata con tallonetta...
# 7      Sneakers 2651 cat  Slip on in pelle color oro effetto intrecciato...
# 8      Sneakers 2651 cat  Slip on in pelle color cuoio effetto intreccia...
# 9         Sneakers 23039  Sneakers in pelle nera con tallonetta color pl...
# 10        Sneakers 23039  Sneakers in pelle bianca con tallonetta color ...
# ...

# %%
pages = pages =  ["https://www.kammi.it/scarpe-donna/sandali-bassi/", 
                  "https://www.kammi.it/scarpe-donna/sandali-bassi/pag2/",
                  "https://www.kammi.it/scarpe-donna/sandali-bassi/pag3/",
                  "https://www.kammi.it/scarpe-donna/sandali-bassi/pag4/",
                 "https://www.kammi.it/scarpe-donna/sandali-bassi/pag5/",
                 "https://www.kammi.it/scarpe-donna/sandali-bassi/pag6/",
                 "https://www.kammi.it/scarpe-donna/sandali-bassi/pag7/",
                 "https://www.kammi.it/scarpe-donna/sandali-bassi/pag8/"]

dict = {"modello": [], "descrizione": [], "prezzo": []}

for url in pages:
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        modelli = soup.find_all("p", attrs={"class": "product-title"})
        descrizioni = soup.find_all("p", attrs={"class": "product-description"})
        prezzi = soup.find_all("p", attrs={"class": "product-price"})
        
        prezzi_clean = [prezzo.text for i, prezzo in enumerate(prezzi) if i % 2 != 0]
        
        for modello, descrizione, prezzo in zip(modelli, descrizioni, prezzi_clean):
            dict["categoria"] = "Sandali bassi"
            dict["modello"].append(modello.text.strip())
            dict["descrizione"].append(descrizione.text.strip())
            dict["prezzo"].append(prezzo.replace("€","").replace(",",".").strip())

df2 = pd.DataFrame(dict)
df2
# Out:
#                modello                                        descrizione  \
# 0         Sandalo 5387  Sandalo laminato argento con fasce a treccia a...
# 1       Sandalo Hellen  Sandalo laminato oro con laccio alla caviglia....
# 2          Sandalo 500                             Sandalo in nappa cuoio
# 3      Sandalo 500 cam                           Sandalo in camoscio rosa
# 4        Sandalo 23368  Sandalo infradito in pelle bianca con allaccia...
# ..                 ...                                                ...
# 114      Sandalo Brusa  Sandalo in pelle bianca incrociata con cinturi...
# 115     Sandalo Kebili  Sandalo infradito con lavorazione etnica con c...
# 116   Sandalo Medenine           Sandalo ultraflat con lavorazione etnica
# 117  Sandalo Marrakech                       Sandalo infradito con pompon
# 118    Infradito Angel        Infradito argento lamè con accessori Silver
#
#     prezzo      categoria
# 0    69.90  Sandali bassi
# ...

# %%
pages = pages =  ["https://www.kammi.it/scarpe-donna/stivali-stivaletti/",
                  "https://www.kammi.it/scarpe-donna/stivali-stivaletti/pag2/"]

dict = {"modello": [], "descrizione": [], "prezzo": []}

for url in pages:
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        modelli = soup.find_all("p", attrs={"class": "product-title"})
        descrizioni = soup.find_all("p", attrs={"class": "product-description"})
        prezzi = soup.find_all("p", attrs={"class": "product-price"})
        
        prezzi_clean = [prezzo.text for i, prezzo in enumerate(prezzi) if i % 2 != 0]
        
        for modello, descrizione, prezzo in zip(modelli, descrizioni, prezzi_clean):
            dict["categoria"] = "Stivali e stivaletti"
            dict["modello"].append(modello.text.strip())
            dict["descrizione"].append(descrizione.text.strip())
            dict["prezzo"].append(prezzo.replace("€","").replace(",",".").strip())

df3 = pd.DataFrame(dict)
df3
# Out:
#                  modello                                        descrizione  \
# 0        Tronchetto 6022  Tronchetto a punta in morbida pelle colore nud...
# 1        Tronchetto 6022  Tronchetto a punta in morbida pelle colore lat...
# 2          Stivale Pazza  Stivale a punta in suede color nero con tacco ...
# 3          Stivale Pazza  Stivale a punta in suede color cuoio con tacco...
# 4        Tronchetto 2929  Tronchetto a punta in pelle latte con cerniera...
# 5        Tronchetto 2929  Tronchetto a punta in pelle avio con cerniera ...
# 6             Texano X02  Stivale texano in pelle nera arricchito da dis...
# 7            Texano 4101  Stivale stile texano scamosciato color camel c...
# 8         Stivale Tex 61  Stivale stile texano in pelle lavorata color n...
# 9            Stivale T97  Stivale in camoscio taupe con laccio posterior...
# 10        Stivaletto 64F  Stivaletto stile texano in camoscio taupe con ...
# ...

# %%
pages = pages =  ["https://www.kammi.it/scarpe-donna/zeppe/",
                  "https://www.kammi.it/scarpe-donna/zeppe/pag2/",
                  "https://www.kammi.it/scarpe-donna/zeppe/pag3/",
                 "https://www.kammi.it/scarpe-donna/zeppe/pag4/"]

dict = {"modello": [], "descrizione": [], "prezzo": []}

for url in pages:
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        modelli = soup.find_all("p", attrs={"class": "product-title"})
        descrizioni = soup.find_all("p", attrs={"class": "product-description"})
        prezzi = soup.find_all("p", attrs={"class": "product-price"})
        
        prezzi_clean = [prezzo.text for i, prezzo in enumerate(prezzi) if i % 2 != 0]
        
        for modello, descrizione, prezzo in zip(modelli, descrizioni, prezzi_clean):
            dict["categoria"] = "Zeppe"
            dict["modello"].append(modello.text.strip())
            dict["descrizione"].append(descrizione.text.strip())
            dict["prezzo"].append(prezzo.replace("€","").replace(",",".").strip())

df4 = pd.DataFrame(dict)
df4
# Out:
#               modello                                        descrizione  \
# 0           Zeppa 102  Zeppa in camoscio terra di siena, tessuto e co...
# 1           Zeppa 100  Zeppa in tessuto rosso e corda, con lacci alla...
# 2           Zeppa 100  Zeppa in tessuto nero e corda, con lacci alla ...
# 3           Zeppa 100  Zeppa in tessuto panna e corda, con lacci alla...
# 4           Zeppa 102  Zeppa in camoscio nero, tessuto e corda, con l...
# 5           Zeppa 102  Zeppa in camoscio beige, tessuto e corda, con ...
# 6          Zeppa 4102  Zeppa platform in pelle grigio chiaro con due ...
# 7        Ciabatta 300  Ciabatta in pelle grigio chiaro con due fasce ...
# 8          Zeppa 2643  Zeppa in pelle lamanita color platino con cint...
# 9          Zeppa 2643  Zeppa in pelle color cognac con cinturini incr...
# 10         Zeppa 2044  Zeppa in pelle nera con cinturini incrociati, ...
# 11         Sabot 2071  Sabot in pelle nera con cinturino, graffette a...
# ...

# %%
pages =   ["https://www.kammi.it/scarpe-donna/sandali-con-tacco/", 
           "https://www.kammi.it/scarpe-donna/sandali-con-tacco/pag2/",
           "https://www.kammi.it/scarpe-donna/sandali-con-tacco/pag3/",
           "https://www.kammi.it/scarpe-donna/sandali-con-tacco/pag4/"
          ]

dict = {"modello": [], "descrizione": [], "prezzo": []}

for url in pages:
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        modelli = soup.find_all("p", attrs={"class": "product-title"})
        descrizioni = soup.find_all("p", attrs={"class": "product-description"})
        prezzi = soup.find_all("p", attrs={"class": "product-price"})
        
        prezzi_clean = [prezzo.text for i, prezzo in enumerate(prezzi) if i % 2 != 0]
        
        for modello, descrizione, prezzo in zip(modelli, descrizioni, prezzi_clean):
            dict["categoria"] = "Sandali con tacco"
            dict["modello"].append(modello.text.strip())
            dict["descrizione"].append(descrizione.text.strip())
            dict["prezzo"].append(prezzo.replace("€","").replace(",",".").strip())

df5 = pd.DataFrame(dict)
df5
# Out:
#                         modello  \
# 0        Sandalo con tacco M054
# 1        Sandalo con tacco M044
# 2        Sandalo con tacco M044
# 3        Sandalo con tacco M044
# 4   Sandalo con tacco 8006 raso
# 5        Sandalo con tacco M044
# 6        Sandalo con tacco 8006
# 7        Sandalo con tacco 8006
# 8        Sandalo con tacco 7012
# 9        Sandalo con tacco 7012
# 10       Sandalo con tacco 8004
# 11       Sandalo con tacco 8004
# 12       Sandalo con tacco 3588
# 13       Sandalo con tacco 3588
# 14                 Sandalo 1789
# 15       Sandalo con tacco 7100
# 16                Sandalo Lione
# 17                 Sandalo 2714
# 18                 Sandalo 1789
# 19                 Sandalo 1789
# 20             Sandalo 9440 lux
# 21                 Sandalo 9440
# 22                 Sandalo 9440
# 23      Sandalo con tacco PL010
# 24      Sandalo con tacco PL010
# 25       Sandalo con tacco 2618
# 26   Sandalo con tacco NO26 Cam
# 27       Sandalo con tacco 3808
# ...

# %%
pages = pages =   ["https://www.kammi.it/scarpe-donna/scarpe-con-tacco/", 
                   "https://www.kammi.it/scarpe-donna/scarpe-con-tacco/pag2/",
                   "https://www.kammi.it/scarpe-donna/scarpe-con-tacco/pag3/",
                   "https://www.kammi.it/scarpe-donna/scarpe-con-tacco/pag4/",
                   "https://www.kammi.it/scarpe-donna/scarpe-con-tacco/pag5/",
                   "https://www.kammi.it/scarpe-donna/scarpe-con-tacco/pag6/",
                   "https://www.kammi.it/scarpe-donna/scarpe-con-tacco/pag7/",
                   "https://www.kammi.it/scarpe-donna/scarpe-con-tacco/pag8/"]

dict = {"modello": [], "descrizione": [], "prezzo": []}

for url in pages:
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        modelli = soup.find_all("p", attrs={"class": "product-title"})
        descrizioni = soup.find_all("p", attrs={"class": "product-description"})
        prezzi = soup.find_all("p", attrs={"class": "product-price"})
        
        prezzi_clean = [prezzo.text for i, prezzo in enumerate(prezzi) if i % 2 != 0]
        
        for modello, descrizione, prezzo in zip(modelli, descrizioni, prezzi_clean):
            dict["categoria"] = "Scarpe  con tacco(Decollete)"
            dict["modello"].append(modello.text.strip())
            dict["descrizione"].append(descrizione.text.strip())
            dict["prezzo"].append(prezzo.replace("€","").replace(",",".").strip())

df6 = pd.DataFrame(dict)
df6
# Out:
#                      modello  \
# 0             Slingback 1621
# 1             Slingback M009
# 2             Slingback 3004
# 3             Slingback 3005
# 4    Mocassino con tacco 512
# ..                       ...
# 105   Scarpa con tacco Trani
# 106   Scarpa Gubbio Craccato
# 107             Bebè Bourges
# 108           Spuntata Monza
# 109     Decolleté in vernice
#
#                                            descrizione  prezzo  \
# 0    Slingback intrecciata sui toni del latte e ner...  135.00
# 1    Sling back charm cipria, tacco 9 cm, soletta i...   89.90
# 2    Sling back in tela nera, tacco 6 cm, soletta i...   95.00
# 3    Sling back in vittor beige, tacco 6 cm, solett...   95.00
# 4    Mocassino stile college in camoscio sella con ...  129.00
# ..                                                 ...     ...
# 105     Scarpa con tacco in vernice cipria tacco 10 cm   39.95
# 106  Scarpa con tacco con allacciatura alla cavigli...   42.50
# ...

# %%
pages = pages =  ["https://www.kammi.it/scarpe-donna/scarpe-basse/",
                  "https://www.kammi.it/scarpe-donna/scarpe-basse/pag2/",
                  "https://www.kammi.it/scarpe-donna/scarpe-basse/pag3/",
                  "https://www.kammi.it/scarpe-donna/scarpe-basse/pag4/",
                  "https://www.kammi.it/scarpe-donna/scarpe-basse/pag5/",
                  "https://www.kammi.it/scarpe-donna/scarpe-basse/pag6/",
                  "https://www.kammi.it/scarpe-donna/scarpe-basse/pag7/",
                  "https://www.kammi.it/scarpe-donna/scarpe-basse/pag8/"] 

dict = {"modello": [], "descrizione": [], "prezzo": []}

for url in pages:
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        modelli = soup.find_all("p", attrs={"class": "product-title"})
        descrizioni = soup.find_all("p", attrs={"class": "product-description"})
        prezzi = soup.find_all("p", attrs={"class": "product-price"})
        
        prezzi_clean = [prezzo.text for i, prezzo in enumerate(prezzi) if i % 2 != 0]
        
        for modello, descrizione, prezzo in zip(modelli, descrizioni, prezzi_clean):
            dict["categoria"] = "Scarpe basse(ballerine, mocassini)"
            dict["modello"].append(modello.text.strip())
            dict["descrizione"].append(descrizione.text.strip())
            dict["prezzo"].append(prezzo.replace("€","").replace(",",".").strip())

df7 = pd.DataFrame(dict)
df7
# Out:
#                        modello  \
# 0               Ballerina 5019
# 1               Ballerina 5016
# 2               Ballerina 5016
# 3               Ballerina 5025
# 4               Mocassino  L48
# ..                         ...
# 103           Mocassino Milano
# 104  Mocassino Milano Laminato
# 105             Ballerina Lace
# 106          Espadrillas Silvy
# 107              Mocassino One
#
#                                            descrizione  prezzo  \
# 0    Ballerina in pelle nera arricchita da fiocchet...  105.00
# 1    Ballerina in pelle nera arricchita da fiocchet...   95.00
# 2    Ballerina in pelle color carne arricchita da f...   95.00
# 3    Ballerina sfilata colore sabbia, arricchita da...  109.00
# 4    Mocassino in tessuto con stampa geometrica e i...  129.00
# ..                                                 ...     ...
# 103        Mocassino in pelle nera con accessorio Gold   34.95
# 104         Mocassino in pelle laminata con accessorio   34.95
# ...

# %%
dfscarpe = [df1, df2, df3, df4, df5, df6, df7]
Kammi = pd.concat(dfscarpe, ignore_index=True)
#Kammi.modello = Kammi.descrizione.str.split(" ",expand=True)[0].replace("Sandali","Sandalo").replace("sandalo","Sandalo")
##Kammi.modello = Kammi.modello.str.replace("Snadalo","Sandalo").replace("Decolletè","Décolleté").replace("Decolleté","Décolleté")
#Kammi.modello = Kammi.modello.str.replace("Texano","Stivale").replace("Stivaletto","Stivale").replace("Tronchetto","Stivale")
#Kammi.modello = Kammi.modello.str.replace("Zeppa","Zeppe").replace("Infradito","Ciabatta").replace("Slipper","Ciabatta")
#Kammi.modello = Kammi.modello.str.replace("Zeppa","Zeppe").replace("Infradito","Ciabatta").replace("Slipper","Ciabatta")
#print(Kammi.modello.unique())
#print(len(Kammi.modello.unique()))
Kammi["sottocategorie"] = Kammi.descrizione.str.split(" ",expand=True)[0].replace("Sandali","Sandalo").replace("sandalo","Sandalo")
Kammi.sottocategorie = Kammi.sottocategorie.str.replace("Snadalo","Sandalo").replace("Decolletè","Décolleté").replace("Decolleté","Décolleté")
Kammi.sottocategorie = Kammi.sottocategorie.str.replace("Texano","Stivale").replace("Stivaletto","Stivale").replace("Tronchetto","Stivale")
Kammi.sottocategorie = Kammi.sottocategorie.str.replace("Zeppa","Zeppe").replace("Infradito","Ciabatta").replace("Slipper","Ciabatta")
Kammi.sottocategorie = Kammi.sottocategorie.str.replace("Zeppa","Zeppe").replace("Infradito","Ciabatta").replace("Slipper","Ciabatta")
print(Kammi.categoria.unique())
print(len(Kammi.categoria.unique()))
print(Kammi.sottocategorie.unique())
print(len(Kammi.sottocategorie.unique()))
# Out:
# ['sneakers' 'Sandali bassi' 'Stivali e stivaletti' 'Zeppe'
#  'Sandali con tacco' 'Scarpe  con tacco(Decollete)'
#  'Scarpe basse(ballerine, mocassini)']
# 7
# ['Sneakers' 'Slip' 'Sandalo' 'Ciabatta' 'Zeppe' 'Stivale' 'Pompierino'
#  'Anfibio' 'Sabot' 'Slingback' 'Sling' 'Mocassino' 'Zoccolo' 'Décolleté'
#  'Scarpa' 'Bebè' 'Spuntata' 'Ballerina' 'Espadrillas' 'Allacciata']
# 20

# %%
Kammi.prezzo = Kammi.prezzo.astype(float)
Kammi
# Out:
#                        modello  \
# 0               Sneakers 82066
# 1               Sneakers 82066
# 2               Sneaker Marina
# 3               Sneaker Marina
# 4                 Sneaker Nina
# ..                         ...
# 481           Mocassino Milano
# 482  Mocassino Milano Laminato
# 483             Ballerina Lace
# 484          Espadrillas Silvy
# 485              Mocassino One
#
#                                            descrizione  prezzo  \
# 0    Sneakers in pelle bianca con inserti verde men...  105.00
# 1    Sneakers in pelle bianca con inserti laminato ...  105.00
# 2    Sneakers in pelle bianca con tallonetta in gli...  109.00
# 3    Sneakers in pelle bianca con tallonetta in gli...  109.00
# 4    Sneakers in pelle bianca, saetta in pelle e gl...  109.00
# ..                                                 ...     ...
# 481        Mocassino in pelle nera con accessorio Gold   34.95
# 482         Mocassino in pelle laminata con accessorio   34.95
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 6))
sns.boxplot(x="categoria", y="prezzo", data=Kammi)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 6))
sns.boxplot(x="modello", y="prezzo", data=Kammi)
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.violinplot(x="modello", y="prezzo", data=Kammi)
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.barplot(x="categoria", y="prezzo", data=Kammi)
plt.show()

# %%
prodotti_per_categoria = Kammi['categoria'].value_counts()
plt.figure(figsize=(10, 6)) 
sns.barplot(x=prodotti_per_categoria.index, y=prodotti_per_categoria.values)
plt.xlabel('Categoria Scarpa')
plt.ylabel('Numero di Prodotti')
plt.title('Conteggio Prodotti per Categoria')
plt.xticks(rotation=45, ha='right')
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Sandali bassi'),
#   Text(1, 0, 'Scarpe  con tacco(Decollete)'),
#   Text(2, 0, 'Scarpe basse(ballerine, mocassini)'),
#   Text(3, 0, 'Zeppe'),
#   Text(4, 0, 'Sandali con tacco'),
#   Text(5, 0, 'sneakers'),
#   Text(6, 0, 'Stivali e stivaletti')])

# %%
prodotti_per_categoria = Kammi['categoria'].value_counts()
plt.figure(figsize=(10, 6))  
sns.boxplot(y=prodotti_per_categoria.values)
plt.ylabel('Numero di Prodotti')
plt.title('Distribuzione del Numero di Prodotti per Categoria')
plt.show()

# %%
gruppo_tipologia = Kammi.groupby('categoria')
statistiche_prezzo = gruppo_tipologia['prezzo'].describe()
statistiche_prezzo
# Out:
#                                     count       mean        std    min  \
# categoria
# Sandali bassi                       119.0  47.935042  17.250271  17.50
# Sandali con tacco                    49.0  61.911224  29.458695  24.95
# Scarpe  con tacco(Decollete)        110.0  83.405727  28.174161  32.50
# Scarpe basse(ballerine, mocassini)  108.0  69.289537  25.713466  27.50
# Stivali e stivaletti                 19.0  86.873684  47.771049  44.95
# Zeppe                                52.0  62.531923  17.583602  29.50
# sneakers                             29.0  85.041034  24.601167  34.50
#
#                                         25%    50%    75%    max
# categoria
# Sandali bassi                       31.2250  48.93   59.9   79.9
# Sandali con tacco                   34.9500  49.50   89.9  119.0
# Scarpe  con tacco(Decollete)        59.5375  79.90   99.9  135.0
# Scarpe basse(ballerine, mocassini)  49.5000  69.90   89.9  129.0
# ...

# %%
statistiche_prezzo['mean'].plot(kind='bar', figsize=(8, 4))
plt.xlabel('Tipologia di Calzature')
plt.ylabel('Prezzo Medio')
plt.title('Prezzo Medio per Tipologia di Calzature')
plt.show()
print(statistiche_prezzo)
# Out:
#                                     count       mean        std    min  \
# categoria
# Sandali bassi                       119.0  47.935042  17.250271  17.50
# Sandali con tacco                    49.0  61.911224  29.458695  24.95
# Scarpe  con tacco(Decollete)        110.0  83.405727  28.174161  32.50
# Scarpe basse(ballerine, mocassini)  108.0  69.289537  25.713466  27.50
# Stivali e stivaletti                 19.0  86.873684  47.771049  44.95
# Zeppe                                52.0  62.531923  17.583602  29.50
# sneakers                             29.0  85.041034  24.601167  34.50
#
#                                         25%    50%    75%    max
# categoria
# Sandali bassi                       31.2250  48.93   59.9   79.9
# Sandali con tacco                   34.9500  49.50   89.9  119.0
# Scarpe  con tacco(Decollete)        59.5375  79.90   99.9  135.0
# Scarpe basse(ballerine, mocassini)  49.5000  69.90   89.9  129.0
# ...

# %%
gruppo_categoria = Kammi.groupby('categoria')
statistiche_prezzo = gruppo_categoria['prezzo'].agg(['mean', 'min', 'max'])
print(statistiche_prezzo)
statistiche_prezzo.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Tipologia di Calzature')
plt.ylabel('Prezzo')
plt.title('Statistiche Prezzo per Tipologia di Calzature')
plt.legend(title='Statistiche')
plt.show()
# Out:
#                                          mean    min    max
# categoria
# Sandali bassi                       47.935042  17.50   79.9
# Sandali con tacco                   61.911224  24.95  119.0
# Scarpe  con tacco(Decollete)        83.405727  32.50  135.0
# Scarpe basse(ballerine, mocassini)  69.289537  27.50  129.0
# Stivali e stivaletti                86.873684  44.95  175.0
# Zeppe                               62.531923  29.50   89.9
# sneakers                            85.041034  34.50  109.0

# %%
gruppo_categoria = Kammi.groupby('sottocategorie')
statistiche_prezzo = gruppo_categoria['prezzo'].agg(['mean', 'min', 'max'])
print(statistiche_prezzo)
statistiche_prezzo.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Tipologia di Calzature')
plt.ylabel('Prezzo')
plt.title('Statistiche Prezzo per Tipologia di Calzature')
plt.legend(title='Statistiche')
plt.show()
# Out:
#                      mean    min     max
# sottocategorie
# Allacciata      49.500000  49.50   49.50
# Anfibio         49.950000  49.95   49.95
# Ballerina       65.009545  27.50  129.00
# Bebè            43.725000  32.50   54.95
# Ciabatta        55.391667  19.95   79.90
# Décolleté       86.625902  34.50  129.00
# Espadrillas     46.792857  27.50   59.90
# Mocassino       85.324000  29.95  129.00
# Pompierino      49.950000  49.95   49.95
# Sabot           67.550000  47.95  115.00
# Sandalo         51.958889  17.50  119.00
# Scarpa          73.087500  32.50  109.00
# Sling           97.355556  49.50  129.00
# Slingback       89.975000  44.95  135.00
# Slip            95.066667  34.50  109.00
# Sneakers        82.425652  39.95  109.00
# Spuntata        44.950000  44.95   44.95
# Stivale         96.720000  44.95  175.00
# Zeppe           63.655333  29.50   89.90
# Zoccolo         95.000000  95.00   95.00

# %%
plt.figure(figsize=(20, 6))  
sns.barplot(x=Kammi.sottocategorie,y=Kammi.prezzo)
plt.ylabel('Prezzo')
plt.title('Distribuzione del Prezzo di Prodotti per Categoria')
plt.show()

# %%
gruppo_stivaletti = Kammi[Kammi.categoria == "Stivali e stivaletti"]

gruppo_stivaletti.sottocategorie.value_counts()
plt.figure(figsize=(10, 6))  
sns.barplot(x=gruppo_stivaletti.sottocategorie,y=gruppo_stivaletti.prezzo)
plt.ylabel('Prezzo')
plt.title('Distribuzione del Prezzo di Prodotti per Categoria')
plt.show()

# %%
gruppo_stivaletti = Kammi[Kammi.categoria == "Stivali e stivaletti"]

gruppo_stivaletti.sottocategorie.value_counts()
plt.figure(figsize=(10, 6))  
sns.countplot(x=gruppo_stivaletti.sottocategorie)
plt.ylabel('Numero di Prodotti')
plt.title('Distribuzione del Numero di Prodotti per SottoCategoria')
plt.show()
